# %%
import os
from supabase import create_client, Client
import pandas as pd

# %%
url = 'https://kxvsvhqboasdghhoepkl.supabase.co'
url
# Out:
# 'https://kxvsvhqboasdghhoepkl.supabase.co'

# %%
key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Imt4dnN2aHFib2FzZGdoaG9lcGtsIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MTM3NTUzODMsImV4cCI6MjAyOTMzMTM4M30.WjAG9RVfytEk9xXKLNRA1IEzeaaUfKZwScc1UGTg9aI'
key
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Imt4dnN2aHFib2FzZGdoaG9lcGtsIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MTM3NTUzODMsImV4cCI6MjAyOTMzMTM4M30.WjAG9RVfytEk9xXKLNRA1IEzeaaUfKZwScc1UGTg9aI'

# %%
sb =  create_client(url, key)
sb

# %%
table = sb.table('mock_data')
table

# %%
table.select('*').execute().data
# Out:
# [{'id': 1,
#   'first_name': 'Merrie',
#   'last_name': 'Goldes',
#   'email': 'mgoldes0@pagesperso-orange.fr',
#   'gender': 'Female',
#   'ip_address': '168.150.208.56'},
#  {'id': 2,
#   'first_name': 'Umberto',
#   'last_name': 'Leaney',
#   'email': 'uleaney1@drupal.org',
#   'gender': 'Male',
#   'ip_address': '255.238.29.87'},
#  {'id': 3,
#   'first_name': 'Genevieve',
#   'last_name': 'Gorwood',
#   'email': 'ggorwood2@fc2.com',
#   'gender': 'Female',
#   'ip_address': '100.194.121.127'},
#  {'id': 4,
#   'first_name': 'Estelle',
#   'last_name': 'Chatto',
#   'email': 'echatto3@bing.com',
#   'gender': 'Female',
#   'ip_address': '77.51.235.237'},
#  {'id': 5,
#   'first_name': 'Donny',
#   'last_name': 'Dadds',
#   'email': 'ddadds4@godaddy.com',
#   'gender': 'Female',
#   'ip_address': '22.98.131.71'},
#  {'id': 6,
#   'first_name': 'Curt',
#   'last_name': 'Raffeorty',
#   'email': 'craffeorty5@amazon.com',
#   'gender': 'Male',
#   'ip_address': '96.36.155.144'},
# ...

# %%
table.select('*').eq('gender', 'Female').execute().data
# Out:
# [{'id': 1,
#   'first_name': 'Merrie',
#   'last_name': 'Goldes',
#   'email': 'mgoldes0@pagesperso-orange.fr',
#   'gender': 'Female',
#   'ip_address': '168.150.208.56'},
#  {'id': 3,
#   'first_name': 'Genevieve',
#   'last_name': 'Gorwood',
#   'email': 'ggorwood2@fc2.com',
#   'gender': 'Female',
#   'ip_address': '100.194.121.127'},
#  {'id': 4,
#   'first_name': 'Estelle',
#   'last_name': 'Chatto',
#   'email': 'echatto3@bing.com',
#   'gender': 'Female',
#   'ip_address': '77.51.235.237'},
#  {'id': 5,
#   'first_name': 'Donny',
#   'last_name': 'Dadds',
#   'email': 'ddadds4@godaddy.com',
#   'gender': 'Female',
#   'ip_address': '22.98.131.71'},
#  {'id': 8,
#   'first_name': 'Victoria',
#   'last_name': 'Caslett',
#   'email': 'vcaslett7@sakura.ne.jp',
#   'gender': 'Female',
#   'ip_address': '61.124.128.173'},
#  {'id': 9,
#   'first_name': 'Lexie',
#   'last_name': 'Marshalleck',
#   'email': 'lmarshalleck8@businessinsider.com',
#   'gender': 'Female',
# ...

# %%
fem = pd.DataFrame(table.select('*').eq('gender', 'Female').execute().data)
fem
# Out:
#     id  first_name       last_name                                email  \
# 0    1      Merrie          Goldes        mgoldes0@pagesperso-orange.fr
# 1    3   Genevieve         Gorwood                    ggorwood2@fc2.com
# 2    4     Estelle          Chatto                    echatto3@bing.com
# 3    5       Donny           Dadds                  ddadds4@godaddy.com
# 4    8    Victoria         Caslett               vcaslett7@sakura.ne.jp
# 5    9       Lexie     Marshalleck    lmarshalleck8@businessinsider.com
# 6   12        Addy       de Zamora                      adezamorab@g.co
# 7   13      Gretel        Sandbach               gsandbachc@shop-pro.jp
# 8   15    Nataline            Newe                   nnewee@t-online.de
# 9   21    Francine          Dimmne                   fdimmnek@imgur.com
# 10  23       Traci           Brogi                    tbrogim@blogs.com
# 11  27      Billye         Cutress                bcutressq@twitter.com
# ...

# %%
table.insert({
    "id" : 101,
    "first_name":"Nephea",
    "last_name":"Cagas",
    "email":"cagas.nephea@gmail.com",
    "gender": "Female",
    "ip_address": "143.143.143.143"
}).execute()
# Out:
# APIResponse[~_ReturnT](data=[{'id': 101, 'first_name': 'Nephea', 'last_name': 'Cagas', 'email': 'cagas.nephea@gmail.com', 'gender': 'Female', 'ip_address': '143.143.143.143'}], count=None)

# %%
table.update({
    "last_name": "Sagac"
}).eq('id', '101').execute()
# Out:
# APIResponse[~_ReturnT](data=[{'id': 101, 'first_name': 'Nephea', 'last_name': 'Sagac', 'email': 'cagas.nephea@gmail.com', 'gender': 'Female', 'ip_address': '143.143.143.143'}], count=None)

# %%
table.delete().eq('id', 101).execute()
# Out:
# APIResponse[~_ReturnT](data=[{'id': 101, 'first_name': 'Nephea', 'last_name': 'Sagac', 'email': 'cagas.nephea@gmail.com', 'gender': 'Female', 'ip_address': '143.143.143.143'}], count=None)
